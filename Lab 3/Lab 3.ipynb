# %%
# !pip install gmplot
import pandas as pd
import ipaddress
import matplotlib.pyplot as plt
import sys
import pycountry
import gmplot
# Out:
# Requirement already satisfied: gmplot in c:\users\lucas\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: requests in c:\users\lucas\anaconda3\lib\site-packages (from gmplot) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lucas\anaconda3\lib\site-packages (from requests->gmplot) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lucas\anaconda3\lib\site-packages (from requests->gmplot) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lucas\anaconda3\lib\site-packages (from requests->gmplot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lucas\anaconda3\lib\site-packages (from requests->gmplot) (3.3)

# %%
data = pd.read_csv("AlienVault_IP_reputation.csv")
data.head(10)
# Out:
#    Unnamed: 0              IP  Reliability  Risk           Type Country  \
# 0           0  222.76.212.189            4     2  Scanning Host      cn
# 1           1  222.76.212.185            4     2  Scanning Host      cn
# 2           2  222.76.212.186            4     2  Scanning Host      cn
# 3           3     5.34.246.67            6     3       Spamming      us
# 4           4   178.94.97.176            4     5  Scanning Host      ua
# 5           5     66.2.49.232            4     2  Scanning Host      us
# 6           6  222.76.212.173            4     2  Scanning Host      cn
# 7           7  222.76.212.172            4     2  Scanning Host      cn
# 8           8  222.76.212.171            4     2  Scanning Host      cn
# 9           9   174.142.46.19            6     3       Spamming     NaN
#
#        Locale                        Coords
# 0      Xiamen    24.4797992706,118.08190155
# 1      Xiamen    24.4797992706,118.08190155
# 2      Xiamen    24.4797992706,118.08190155
# 3         NaN                    38.0,-97.0
# 4      Merefa   49.8230018616,36.0507011414
# 5  Union City  37.5962982178,-122.065696716
# 6      Xiamen    24.4797992706,118.08190155
# 7      Xiamen    24.4797992706,118.08190155
# 8      Xiamen    24.4797992706,118.08190155
# 9         NaN    24.4797992706,118.08190155

# %%
#task 1
print(data.describe())
for col in data.select_dtypes(include='object'):
    print(f"Column: {col}")
    print(data[col].value_counts())
    print(data[col].unique())
# Out:
#         Unnamed: 0   Reliability          Risk
# count  10000.00000  10000.000000  10000.000000
# mean    4999.50000      4.004800      2.545900
# std     2886.89568      0.920033      0.776372
# min        0.00000      1.000000      1.000000
# 25%     2499.75000      4.000000      2.000000
# 50%     4999.50000      4.000000      2.000000
# 75%     7499.25000      4.000000      3.000000
# max     9999.00000     10.000000      6.000000
# Column: IP
# 222.76.212.189     1
# 195.226.218.127    1
# 195.226.218.113    1
# 195.226.218.133    1
# 195.226.218.132    1
#                   ..
# 58.59.162.52       1
# 58.59.162.112      1
# 58.59.162.107      1
# 58.59.162.54       1
# 86.35.30.74        1
# Name: IP, Length: 10000, dtype: int64
# ['222.76.212.189' '222.76.212.185' '222.76.212.186' ... '86.35.30.72'
#  '86.35.30.73' '86.35.30.74']
# Column: Type
# Scanning Host                          9038
# Spamming                                336
# Malware IP                              203
# Malware Domain                          195
# Malicious Host                          172
# C&C                                      31
# Malicious Host;Scanning Host              6
# Malware Domain;Malware IP                 6
# Scanning Host;Malicious Host              3
# Scanning Host;Malware Domain              2
# Malware Domain;Scanning Host              2
# C&C;Scanning Host                         1
# Malware IP;Malware Domain                 1
# Malware Domain;Malicious Host             1
# C&C;Malware Domain                        1
# Scanning Host;C&C                         1
# Malware distribution;Malicious Host       1
# Name: Type, dtype: int64
# ['Scanning Host' 'Spamming' 'Malware IP' 'Malware Domain' 'Malicious Host'
#  'C&C' 'Malware Domain;Malicious Host' 'Malware Domain;Malware IP'
#  'Malware Domain;Scanning Host' 'C&C;Scanning Host'
#  'Malicious Host;Scanning Host' 'Scanning Host;Malware Domain'
#  'Malware IP;Malware Domain' 'Scanning Host;Malicious Host'
#  'C&C;Malware Domain' 'Scanning Host;C&C'
#  'Malware distribution;Malicious Host']
# Column: Country
# us    2194
# cn    2125
# de     428
# br     393
# nl     350
#       ...
# be       1
# il       1
# ee       1
# az       1
# kz       1
# Name: Country, Length: 73, dtype: int64
# ['cn' 'us' 'ua' nan 'de' 'kr' 'br' 'nl' 'ca' 'id' 'lv' 'ru' 'tw' 'tr' 'gb'
#  'pt' 'ro' 'fr' 'pl' 'hk' 'rs' 'in' 'es' 'md' 'ph' 'ir' 'eg' 'th' 'pk'
#  'cy' 'cz' 'lk' 'se' 'sg' 'nz' 'za' 'sa' 'cl' 'ge' 'at' 'hu' 'by' 'it'
#  'dk' 'be' 'no' 'gr' 'il' 'vn' 'jp' 'ee' 'kz' 'fi' 'jo' 'az' 'bg' 'ar'
#  'pe' 'mx' 've' 'gt' 'uy' 'do' 'pa' 'ae' 'lu' 'ma' 'ch' 'vg' 'au' 'lt'
#  'ec' 'sm' 'my']
# Column: Locale
# Jinan             323
# Shanghai          300
# Belo Horizonte    206
# Woodbridge        195
# Santiago          194
#                  ...
# Fortaleza           1
# Simi Valley         1
# Newark              1
# Rock Hill           1
# Reno                1
# Name: Locale, Length: 310, dtype: int64
# ['Xiamen' nan 'Merefa' 'Union City' 'Nanjing' 'Foshan' 'Nanchang' 'Boston'
#  'Chicago' 'Henderson' 'Jinan' 'Matawan' 'Chengdu' 'Kiev' 'Baotou'
#  'Fremont' 'Santa Clara' 'Scottsdale' 'Bellevue' 'Phoenix' 'Los Angeles'
#  'Taipei' 'Hangzhou' 'Beijing' 'Walnut' 'Clarks Summit' 'Istanbul'
#  'Guangzhou' 'Kunming' 'Gloucester' 'London' 'Porto' 'Gheorgheni' 'Tempe'
#  'Caransebes' 'Henan' 'Columbus' 'Houston' 'Kansas City' 'Myrtle Beach'
#  'Alhambra' 'Amsterdam' 'Porto Alegre' 'Wuhan' 'Lansing' 'Santa Monica'
#  'Frankfurt' 'Eastlake' 'Kwun Tong' 'Green Bay' 'Kirkland' 'Pune'
#  'Chisinau' 'Shenyang' 'Diamond Bar' 'Sampaloc' 'Pars' 'Rajkot'
#  'Ann Arbor' 'Chongqing' 'Toronto' 'Bangkok' 'Orlando' 'Ghaziabad'
#  'Belo Horizonte' 'Islamabad' 'Oxford' 'Media' 'Seattle' 'Ankara'
#  'Stavropol' 'Redwood City' 'Conroe' 'San Francisco' 'Sherwood' 'Drochia'
#  'Napier' 'Salt Lake City' 'Cairo' 'Irkutsk' 'Orange' 'Novi' 'Lai Chi Kok'
#  'Provo' 'Dallas' 'Wayne' 'Buffalo' 'Eskisehir' 'Samsun' 'Satka'
#  'Pittsburgh' 'Shanghai' 'Ahwaz' 'Absecon' 'San Antonio' 'Clifton'
#  'Qingdao' 'Calcutta' 'Kolkata' 'Hoboken' 'Changsha' 'Riyadh' 'Salvador'
#  'Verl' 'Faridabad' 'Ulyanovsk' 'Portland' 'New York' 'League City'
#  'Capelle Aan Den Ijssel' 'La Union' 'Paris' 'Wiener Neustadt' 'Kenmore'
#  'Laval' 'San Jose' 'Bluffton' 'Zhengzhou' 'Fuzhou' 'Ugur'
#  'Rancho Cucamonga' 'Chantilly' 'Missoula' 'Nanning' 'Berlin' 'Warsaw'
#  'Bristol' 'Delsbo' 'Seoul' 'Omsk' 'Nivelles' 'Bauru' 'Bergen'
#  'Culver City' 'Qinhuangdao' 'Tangshan' 'Tel Aviv' 'Victorville'
#  'Barcelona' 'Madrid' 'Saint Louis' 'Hanoi' 'Tokyo' 'West Palm Beach'
#  'Changchun' 'Mumbai' 'Taichung' 'Teramo' 'Bracciano' 'Hefei' 'Hanover'
#  'Moscow' 'Commerce Township' 'Harbin' 'Sanayi' 'Bangor' 'Kisa'
#  'Nizhniy Novgorod' 'Hyderabad' 'Atlanta' 'Washington' 'Burlington'
#  'Central District' 'Sayre' 'Sacramento' 'Secaucus' 'Bethesda' 'Santiago'
#  'Karagandy' 'Lublin' 'Kaluga' 'Singapore' 'Salzburg' 'Kocaeli'
#  'Targoviste' 'Nonthaburi' 'Fortaleza' 'Simi Valley' 'Saint Petersburg'
#  'Newark' 'Donetsk' 'Rock Hill' 'Dayton' 'Brea' 'Tucuman' 'Scranton'
#  'Karachi' 'Lima' 'Teoloyucan' 'Brovary' 'Montevideo' 'Temple'
#  'Woodbridge' 'Mars' 'Kharkov' 'Joliet' 'Logansport' 'Linares'
#  'Puerto Montt' 'Ashiya' 'Boca Raton' 'Old Bridge' 'Francesco'
#  'Jersey City' 'Overland Park' 'Banda Del Rio Sali' 'Grand Rapids'
#  'Canoas' 'Dourados' 'Zapopan' 'Guadalajara' 'Campeche' 'Chilpancingo'
#  'Mexico' 'Naucalpan' 'Jarinu' 'Lenoir' 'Assis' 'Guarapari' 'Ulysses'
#  'Shenzhen' 'Pompano Beach' 'Santo Domingo' 'Al Ain' 'Vancouver'
#  'Costa Mesa' 'La Rioja' 'Riga' 'Oakville' 'Tulsa' 'Mentor' 'Kamensk'
#  'Hebei' 'Casablanca' 'Amman' 'Jacksonville' 'Westlake Village' 'Bradley'
#  'Fulshear' 'Denver' 'Gaziantep' 'Yerba Buena' 'Fastov' 'Ivanov' 'Orpund'
#  'Oklahoma City' 'Canyon Country' 'New Delhi' 'Dnepropetrovsk' 'Groningen'
#  'Jakarta' 'Hiroshima' 'Lenexa' 'Caracas' 'Amagasaki' 'Siauliai'
#  'Carson City' 'Xian' 'Burgstetten' 'South Bend' 'Savage' 'Pasargad'
#  'Quito' 'Santimbru' 'Rio Branco' 'Plock' 'Binzhou' 'Perm' 'Sabz'
#  'Raleigh' 'Izmir' 'Leinfelden-echterdingen' 'Sharjah' 'Olivos' 'Rivne'
#  'Birmingham' 'Bronx' 'Den Burg' 'Beaumaris' 'Gladewater' 'Fullerton'
#  'Morristown' 'Findlay' 'Ashburn' 'Rimouski' 'San Diego' 'Shangrao'
#  'Fort Lauderdale' 'Miami' 'Las Vegas' 'Brasov' 'Salta' 'Bangalore'
#  'Jujuy' 'Baia Mare' 'Suzhou' 'Oita' 'Sevastopol' 'Dubai' 'Zaoyang'
#  '5.64699983597,100.487701416' '26.1208992004,-80.1272964478'
#  '50.2975997925,18.6765995026' '40.8554992676,-74.1268005371'
#  '42.0167007446,24.8666992188' '41.8776016235,-87.6271972656'
#  '-23.4333000183,-45.0666999817' '39.14220047,117.176696777'
#  '50.9426002502,16.4957008362' '56.7209014893,10.1140003204'
#  '34.8600997925,-82.2463989258' '47.2667007446,10.9333000183'
#  '39.4896011353,-119.749198914']

# %%
#task 2
data['subnet'] = data['IP'].apply(lambda x: '.'.join(x.split('.')[:3]) + '.0')
unique_subnets = data['subnet'].nunique()
print(f"There are {unique_subnets} unique 24-bit subnet addresses in the dataset.")
subnet_count = data[data['subnet'] == '222.76.212.0'].shape[0]
print(f"There are {subnet_count} IP addresses in the CIDR block 222.76.212.0/24.")
subnet_count = data[data['subnet'] == '5.34.246.0'].shape[0]
print(f"There are {subnet_count} IP addresses in the CIDR block 5.34.246.0/24.")
# Out:
# There are 1037 unique 24-bit subnet addresses in the dataset.
# There are 22 IP addresses in the CIDR block 222.76.212.0/24.
# There are 3 IP addresses in the CIDR block 5.34.246.0/24.

# %%
#task 3
data['ip_address'] = data['IP'].apply(ipaddress.IPv4Address)
cidr_block = ipaddress.IPv4Network('222.76.212.0/24')
data.loc[data['ip_address'].apply(lambda x: x in cidr_block), 'Risk'] = data['Risk']
avg_risk_score = data['Risk'].mean()

print(f"The average risk score for the IP addresses in CIDR block 222.76.212.0/24 is {avg_risk_score:.2f}.")
# Out:
# The average risk score for the IP addresses in CIDR block 222.76.212.0/24 is 2.55.

# %%
#Task 4
us_df = data[data['Country'] == 'us']
cn_df = data[data['Country'] == 'cn']
us = us_df['Risk'].mean()
cn = cn_df['Risk'].mean()
risk_score_gap = us_avg_risk_score - cn_avg_risk_score

print(f"The average risk score for 'US' geo-located IP addresses is {us:.2f}.")
print(f"The average risk score for 'CN' geo-located IP addresses is {cn:.2f}.")
print(f"The gap in risk scores between 'US' and 'CN' geo-located IP addresses is {risk_score_gap:.2f}.")
# Out:
# The average risk score for 'US' geo-located IP addresses is 2.33.
# The average risk score for 'CN' geo-located IP addresses is 2.43.
# The gap in risk scores between 'US' and 'CN' geo-located IP addresses is -0.10.

# %%
#task 5
countr_name_list=[]
country_name_list=[]
for cc in data['Country']:
    cc=str(cc).lower()
    if not (cc=='nan'):
        country_name = pycountry.countries.lookup(cc).name
        country_name_list.append(country_name)
    else:
        country_name_list.append('nan')

data['country_name']= country_name_list

# %%
countries = ['Ukraine', 'Russian Federation', 'United Kingdom', 'Mexico', 'Pakistan']
df = data[data['country_name'].isin(countries)]
for country in countries:
    count = len(df[df['country_name'] == country])
    print(f"There are {count} IP addresses in the dataset associated with {country}.")
# Out:
# There are 322 IP addresses in the dataset associated with Ukraine.
# There are 210 IP addresses in the dataset associated with Russian Federation.
# There are 266 IP addresses in the dataset associated with United Kingdom.
# There are 145 IP addresses in the dataset associated with Mexico.
# There are 165 IP addresses in the dataset associated with Pakistan.

# %%
#task 6
countries = ['United States', 'Russian Federation']
filtered_df = data[data['country_name'].isin(countries)]
us_rel = filtered_df[filtered_df['country_name'] == 'United States']['Reliability'].mean()
ru_rel = filtered_df[filtered_df['country_name'] == 'Russian Federation']['Reliability'].mean()
rel_gap = abs(us_rel - ru_rel);

print(f"The average reliability score for the United States is {us_rel:.2f}.")
print(f"The average reliability score for the Russian Federation is {ru_rel:.2f}.")
print(f"The reliability gap between United States and Russian Federation is {rel_gap:.2f}.")
# Out:
# The average reliability score for the United States is 4.31.
# The average reliability score for the Russian Federation is 4.28.
# The reliability gap between United States and Russian Federation is 0.03.

# %%
#Task 7
lat_list = []
long_list= []

for coord in data['Coords']:
    lat_long = coord.split(',')
    lat= lat_long[0]
    lon = lat_long[1]
    lat_list.append(float(lat))
    long_list.append(float(lon))

data['lat'] = lat_list
data['lon'] = long_list

# %%
australia_df = data[data['Country'] == 'Australia']
gmap = gmplot.GoogleMapPlotter(-25.2744, 133.7751, 4)
for i, row in australia_df.iterrows():
    gmap.marker(row['lat'], row['lon'], title=row['IP Address'])

gmap.draw('australia_map.html')

# %%
#Task 8
def attack_types(country):
    country_data = data[data['country_name'] == country]
    attack_types = country_data['Type'].value_counts().head(3)
    return attack_types

us = attack_types('United States')
ger = attack_types('Germany')
china = attack_types('China')

print('Top 3 attack types in the United States:')
print(us)
print('Top 3 attack types in Germany:')
print(ger)
print('Top 3 attack types in China:')
print(china)
# Out:
# Top 3 attack types in the United States:
# Scanning Host    1758
# Spamming          267
# Malware IP         73
# Name: Type, dtype: int64
# Top 3 attack types in Germany:
# Scanning Host     381
# Malware Domain     20
# Malware IP         14
# Name: Type, dtype: int64
# Top 3 attack types in China:
# Scanning Host     2053
# Malicious Host      37
# Malware Domain      26
# Name: Type, dtype: int64

# %%
#Task 9
cr = data.groupby('country_name')['Risk'].mean()

cr_sorted= country_risk.sort_values(ascending=False)

top_five = cr_sorted.head(5)

print("Top 5 countries with the highest average risk scores:")
print(top_five)
# Out:
# Top 5 countries with the highest average risk scores:
# country_name
# Finland                    9.0
# Hungary                    6.5
# Cyprus                     6.0
# Sri Lanka                  6.0
# Virgin Islands, British    6.0
# Name: Reliability, dtype: float64

# %%
#task 10
crel = data.groupby('country_name')['Reliability'].mean()

crel_sorted = country_rel.sort_values(ascending=False)

top_five = crel_sorted.head(5)

print("Top 5 countries with highest average Reliability scores:")
print(top_five)
# Out:
# Top 5 countries with highest average Reliability scores:
# country_name
# Finland                    9.0
# Hungary                    6.5
# Cyprus                     6.0
# Sri Lanka                  6.0
# Virgin Islands, British    6.0
# Name: Reliability, dtype: float64

# %%
#extra 
def get_subnet(ip):
    ip_list = ip.split('.')
    subnet_list = ip_list[:3]
    subnet_list.append('0')
    subnet = '.'.join(subnet_list)
    return subnet

data['subnet'] = data['IP'].apply(get_subnet)
unique_subnets = data['subnet'].nunique()
print("There are", unique_subnets, "unique 24 bit subnet addresses in the dataset.")
subnet_risk = data.groupby('subnet')['Risk'].mean().reset_index()
subnet_risk.columns = ['subnet', 'subnet_risk']
print(subnet_risk.head())
# Out:
# There are 1037 unique 24 bit subnet addresses in the dataset.
#        subnet  subnet_risk
# 0   1.0.232.0          4.0
# 1  1.26.119.0          3.0
# 2  1.36.226.0          2.0
# 3    1.93.4.0          2.0
# 4   1.93.45.0          2.0
